# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Load Data

# %%
file_path = '/content/drive/MyDrive/Colab Notebooks/Day 1/5. Concatenate Columns/Sample - Superstore_table.xlsx'
df = pd.read_excel(file_path)

# %%
df.head(5)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16  Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18        Middle    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18        Middle    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
#only use product related field
df_product= df[["Product ID",	"Category",	"Sub-Category",	"Product Name"]]

# %%
df_product.head()
# Out:
#         Product ID         Category Sub-Category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# 1  FUR-CH-10000454        Furniture       Chairs
# 2  OFF-LA-10000240  Office Supplies       Labels
# 3  FUR-TA-10000577        Furniture       Tables
# 4  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name
# 0                  Bush Somerset Collection Bookcase
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 2  Self-Adhesive Address Labels for Typewriters b...
# 3      Bretford CR4500 Series Slim Rectangular Table
# 4                     Eldon Fold 'N Roll Cart System

# %% [markdown]
# # Concatenate two string columns

# %%
#Concatenate column 'Category' and 'Sub-Category' to become 'full_category' column
df_product['full_category'] = df_product['Category'] + "-" + df_product['Sub-Category']
# Out:
# <ipython-input-8-7057a79b6d7b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_product['full_category'] = df_product['Category'] + "-" + df_product['Sub-Category']

# %%
# The Results
df_product[['Category','Sub-Category','full_category']].head()
# Out:
#           Category Sub-Category            full_category
# 0        Furniture    Bookcases      Furniture-Bookcases
# 1        Furniture       Chairs         Furniture-Chairs
# 2  Office Supplies       Labels   Office Supplies-Labels
# 3        Furniture       Tables         Furniture-Tables
# 4  Office Supplies      Storage  Office Supplies-Storage
