# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Load Data

# %%
file_path = '/content/drive/MyDrive/Colab Notebooks/Day 1/6. Calculated Field/Sample - Superstore_table.xlsx'
df = pd.read_excel(file_path)

# %%
#using field that can be calculated
df[['Order ID','Sales', 'Quantity', 'Profit']].head()
# Out:
#          Order ID     Sales  Quantity    Profit
# 0  CA-2016-152156  261.9600         2   41.9136
# 1  CA-2016-152156  731.9400         3  219.5820
# 2  CA-2016-138688   14.6200         2    6.8714
# 3  US-2015-108966  957.5775         5 -383.0310
# 4  US-2015-108966   22.3680         2    2.5164

# %% [markdown]
# # Summation of 'Sales' and 'Profit'

# %%
#1. Basic Artithmetic
df['Total_Revenue'] = df['Sales'] + df['Profit']

# %%
#2. Using 'eval' method
df.eval('Total_Revenue = Sales + Profit', inplace=True)

# %%
#3. Using 'assign' method
df = df.assign(Total_Revenue=df['Sales'] + df['Profit'])

# %%
df[['Order ID','Sales', 'Quantity', 'Profit','Total_Revenue']].head()
# Out:
#          Order ID     Sales  Quantity    Profit  Total_Revenue
# 0  CA-2016-152156  261.9600         2   41.9136       303.8736
# 1  CA-2016-152156  731.9400         3  219.5820       951.5220
# 2  CA-2016-138688   14.6200         2    6.8714        21.4914
# 3  US-2015-108966  957.5775         5 -383.0310       574.5465
# 4  US-2015-108966   22.3680         2    2.5164        24.8844

# %% [markdown]
# # Squares and Square Roots of 'Sales'

# %%
#4. Use a Function to Square Sales
def square_value(x):
    return x ** 2

df['squared_sales'] = df['Sales'].apply(square_value)

# %%
#5. Use a Numpy Function to Square Roots Sales
import numpy as np

df['sqrt_sales'] = np.sqrt(df['Sales'])

# %%
df[['Order ID','Sales', 'squared_sales','sqrt_sales']].head()
# Out:
#          Order ID     Sales  squared_sales  sqrt_sales
# 0  CA-2016-152156  261.9600   68623.041600   16.185178
# 1  CA-2016-152156  731.9400  535736.163600   27.054390
# 2  CA-2016-138688   14.6200     213.744400    3.823611
# 3  US-2015-108966  957.5775  916954.668506   30.944749
# 4  US-2015-108966   22.3680     500.327424    4.729482
